# %% [markdown]
# # Brazil Housing

# %% [markdown]
#  Business Objective: Analyse and figure out the suitable cities for relocation for Bachelors, for Mid-sized families and for Large families.

# %% [markdown]
# ## Importing the necessary libraries

# %%
import matplotlib.pyplot as plt             
from tabulate import tabulate              
import matplotlib as mat                    
import seaborn as sns                       
import pandas as pd                        
import numpy as np

# %% [markdown]
# ## Reading the file

# %%
df = pd.read_csv("DS1_C5_S3_BazilHousing_Data_Hackathon.csv")
df
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 0           São Paulo    70      2         1               1      7
# 1           São Paulo   320      4         4               0     20
# 2        Porto Alegre    80      1         1               1      6
# 3        Porto Alegre    51      2         1               0      2
# 4           São Paulo    25      1         1               0      1
# ...               ...   ...    ...       ...             ...    ...
# 10687    Porto Alegre    63      2         1               1      5
# 10688       São Paulo   285      4         4               4     17
# 10689  Rio de Janeiro    70      3         3               0      8
# 10690  Rio de Janeiro   120      2         2               2      8
# 10691       São Paulo    80      2         1               0      0
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 0          acept      furnished      2065              3300
# ...

# %% [markdown]
# ## Level 0 Analysis: Understanding the Data

# %% [markdown]
# -> Reading the Top 5 Rows

# %%
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces  floor     animal  \
# 0     São Paulo    70      2         1               1      7      acept
# 1     São Paulo   320      4         4               0     20      acept
# 2  Porto Alegre    80      1         1               1      6      acept
# 3  Porto Alegre    51      2         1               0      2      acept
# 4     São Paulo    25      1         1               0      1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# ...

# %% [markdown]
#  Reading the Bottom 5 Rows

# %%
df.tail()
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 10687    Porto Alegre    63      2         1               1      5
# 10688       São Paulo   285      4         4               4     17
# 10689  Rio de Janeiro    70      3         3               0      8
# 10690  Rio de Janeiro   120      2         2               2      8
# 10691       São Paulo    80      2         1               0      0
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 10687  not acept      furnished       402              1478
# 10688      acept  not furnished      3100             15000
# 10689  not acept      furnished       980              6000
# 10690      acept      furnished      1585             12000
# 10691      acept  not furnished         0              1400
#
#        property tax (R$)  fire insurance (R$)  total (R$)
# 10687                 24                   22        1926
# 10688                973                  191       19260
# ...

# %% [markdown]
#  Number of Rows and Columns

# %%
print(df.shape)
# Out:
# (10692, 13)

# %% [markdown]
#  Display the Names of all the Columns

# %%
df.columns
# Out:
# Index(['city', 'area', 'rooms', 'bathroom', 'parking spaces', 'floor',
#        'animal', 'furniture', 'hoa (R$)', 'rent amount (R$)',
#        'property tax (R$)', 'fire insurance (R$)', 'total (R$)'],
#       dtype='object')

# %% [markdown]
#  Displaying the Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   city                 10692 non-null  object
#  1   area                 10692 non-null  int64
#  2   rooms                10692 non-null  int64
#  3   bathroom             10692 non-null  int64
#  4   parking spaces       10692 non-null  int64
#  5   floor                10692 non-null  int64
#  6   animal               10692 non-null  object
#  7   furniture            10692 non-null  object
#  8   hoa (R$)             10692 non-null  int64
#  9   rent amount (R$)     10692 non-null  int64
#  10  property tax (R$)    10692 non-null  int64
#  11  fire insurance (R$)  10692 non-null  int64
#  12  total (R$)           10692 non-null  int64
# dtypes: int64(10), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
#  Count of Non-Null records

# %%
print("Total number of Non-null records in the given data")
df.count()
# Out:
# Total number of Non-null records in the given data
# city                   10692
# area                   10692
# rooms                  10692
# bathroom               10692
# parking spaces         10692
# floor                  10692
# animal                 10692
# furniture              10692
# hoa (R$)               10692
# rent amount (R$)       10692
# property tax (R$)      10692
# fire insurance (R$)    10692
# total (R$)             10692
# dtype: int64

# %% [markdown]
#  Datatypes of each records

# %%
print("The Datatypes of each records")
df.dtypes
# Out:
# The Datatypes of each records
# city                   object
# area                    int64
# rooms                   int64
# bathroom                int64
# parking spaces          int64
# floor                   int64
# animal                 object
# furniture              object
# hoa (R$)                int64
# rent amount (R$)        int64
# property tax (R$)       int64
# fire insurance (R$)     int64
# total (R$)              int64
# dtype: object

# %% [markdown]
#  Checking if there are Null values in any columns

# %%
df.isnull().sum()
# Out:
# city                   0
# area                   0
# rooms                  0
# bathroom               0
# parking spaces         0
# floor                  0
# animal                 0
# furniture              0
# hoa (R$)               0
# rent amount (R$)       0
# property tax (R$)      0
# fire insurance (R$)    0
# total (R$)             0
# dtype: int64

# %% [markdown]
# There are no null values in the given data.

# %% [markdown]
# From the understanding of the data, the cities 'São Paulo' and 'Rio de Janeiro' are very expensive as we are figuring out of the cities which are less expensive, dropping those cities from the given data.

# %%
df=df.drop(df[(df['city']=='São Paulo')|(df['city']=='Rio de Janeiro')].index)
df
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 2        Porto Alegre    80      1         1               1      6
# 3        Porto Alegre    51      2         1               0      2
# 11           Campinas    46      1         1               1     10
# 15           Campinas   330      4         6               6      0
# 21     Belo Horizonte    42      1         1               1     17
# ...               ...   ...    ...       ...             ...    ...
# 10667  Belo Horizonte    75      2         1               1      3
# 10673    Porto Alegre   220      3         2               2     15
# 10676    Porto Alegre    40      1         1               0      1
# 10682    Porto Alegre   160      3         2               3      4
# 10687    Porto Alegre    63      2         1               1      5
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 2          acept  not furnished      1000              2800
# ...

# %% [markdown]
# ## Level 1 Analysis

# %% [markdown]
#  Separating Categorical and Numerical Variables

# %%
def seprate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:                
        if df[column].nunique() < 100:       
                                                    
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous 


categorical, continuous = seprate_data_types(df)         


from tabulate import tabulate

print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["Categorical", "Continuous"]))
# Out:
# Categorical     Continuous
# --------------  -------------------
# city            area
# rooms           hoa (R$)
# bathroom        rent amount (R$)
# parking spaces  property tax (R$)
# floor           fire insurance (R$)
# animal          total (R$)
# furniture

# %% [markdown]
# ## Level 1: Univariate Analysis

# %% [markdown]
#  User-defined function for level 1 analysis of Categorical columns

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") 
    print(f"Mode of {col} is {df[col].mode()[0]}")  
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}")

# %% [markdown]
# Checking for the:

# %% [markdown]
# - Unique values

# %% [markdown]
# - Mode

# %% [markdown]
# - Total count of missing values

# %%
info_of_cat("city")
# Out:
# Unique values in city are: ['Porto Alegre' 'Campinas' 'Belo Horizonte']
# Mode of city is Belo Horizonte
# Number of missing values in city is 0

# %%
info_of_cat("rooms")
# Out:
# Unique values in rooms are: [ 1  2  4  3  5  6  7 10  8]
# Mode of rooms is 2
# Number of missing values in rooms is 0

# %%
info_of_cat("bathroom")
# Out:
# Unique values in bathroom are: [ 1  6  2  3  4  7  5  8 10]
# Mode of bathroom is 1
# Number of missing values in bathroom is 0

# %%
info_of_cat("parking spaces")
# Out:
# Unique values in parking spaces are: [1 0 6 4 2 3 8 5 7]
# Mode of parking spaces is 1
# Number of missing values in parking spaces is 0

# %%
info_of_cat("floor")
# Out:
# Unique values in floor are: [  6   2  10   0  17  11   7   5  13   1   9   3   4   8  14  16  12  22
#   19  20  15  18 301  26  21  29  51  23]
# Mode of floor is 0
# Number of missing values in floor is 0

# %%
info_of_cat("animal")
# Out:
# Unique values in animal are: ['acept' 'not acept']
# Mode of animal is acept
# Number of missing values in animal is 0

# %%
info_of_cat("furniture")
# Out:
# Unique values in furniture are: ['not furnished' 'furnished']
# Mode of furniture is not furnished
# Number of missing values in furniture is 0

# %% [markdown]
# There are no missing values for each records.

# %% [markdown]
#  Visual presentation of each attribute

# %% [markdown]
# ### Analysis of City column:-

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Number of Houses in each Cities")
ax[1].set_title("Percentage of Houses in each Cities")
percentage = df["city"].value_counts()         
labels = list(df["city"].value_counts().index) 

sns.countplot(x = df["city"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### Interpretation- The City 'Belo Horizonte' is showing 38%, the higher number for the Houses for rent and 'Campinas' is having less number for the rent houses.

# %% [markdown]
# ### Analysis of Rooms column:-

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Number of Rooms available")    
ax[1].set_title("Percentage of Rooms in each Cities")
percentage = df["rooms"].value_counts()         
labels = list(df["rooms"].value_counts().index) 

sns.countplot(x = df["rooms"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### Interpretation- Most of the Houses is having the number of Rooms as '2'.

# %% [markdown]
# ### Analysis of Bathroom column:-

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Number of Bathrooms available")    
ax[1].set_title("Percentage of Bathrooms in each Cities")
percentage = df["bathroom"].value_counts()         
labels = list(df["bathroom"].value_counts().index) 

sns.countplot(x = df["bathroom"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### Interpretation- 45% of the Houses are having atleast 1 Bathroom. 28% of the Houses are having 2 bathrooms and 13% are having 3 bathrooms in the houses.

# %% [markdown]
# ### Analysis of Parking Spaces column:-

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Number of Parking Spaces available")   
ax[1].set_title("Percentage of Parking Spaces in each Cities")
percentage = df["parking spaces"].value_counts()         
labels = list(df["parking spaces"].value_counts().index) 

sns.countplot(x = df["parking spaces"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### Interpretation- 38% houses are having the number of Parking spaces as '1'. 24% of the houses are not having any parking spaces and 20% of the houses are having their parking space count as '2'.

# %% [markdown]
# ### Analysis of  Floor column:-

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 7))
ax[0].set_title("Number of Floors available")      
ax[1].set_title("Percentage of Floors in each Cities")
percentage = df["floor"].value_counts()         
labels = list(df["floor"].value_counts().index) 

sns.countplot(x = df["floor"], ax = ax[0])
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation = 40 , ha = "right")
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")   


plt.show()

# %% [markdown]
# ### Interpretation- 22% are having 0 Floored Houses and 12% of the houses are having atleast 1 floor and 13% of the houses are having 2 floors.

# %% [markdown]
# ### Analysis of Animal column:-

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Animals accept or not accept")
ax[1].set_title("Percentage of Animals accept or not accept")
percentage = df["animal"].value_counts()         
labels = list(df["animal"].value_counts().index) 

sns.countplot(x = df["animal"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### Interpretation- 80% of the houses are allowing Animals and 20% arenot accepting any animals in their houses.

# %% [markdown]
# ### Analysis of Furniture column:-

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Number of houses Furnished and Not Furnished")    
ax[1].set_title("Percentage of Houses Furnished and Not Furnished")
percentage = df["furniture"].value_counts()         
labels = list(df["furniture"].value_counts().index) 

sns.countplot(x = df["furniture"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  

plt.show()

# %% [markdown]
# ### Interpretation- 82% of the houses are Furnished and 18% are not furnished.

# %% [markdown]
# ## Level 2 Analysis

# %% [markdown]
# ### Bivariate Analysis

# %%
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["Categorical", "Continuous"]))
# Out:
# Categorical     Continuous
# --------------  -------------------
# city            area
# rooms           hoa (R$)
# bathroom        rent amount (R$)
# parking spaces  property tax (R$)
# floor           fire insurance (R$)
# animal          total (R$)
# furniture

# %% [markdown]
# ### Relationship of City with Rooms

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "rooms", hue = "city", data = df)
plt.show()

# %% [markdown]
# ### Interpretation- The city 'Porto Alegra' is having the higher number for houses with rooms 1 and also with rooms 2. 'Belo Horizonte' is having higher number of houses with rooms 3 and also with rooms 4.

# %% [markdown]
# ### Relationship of City with Bathrooms

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "bathroom", hue = "city", data = df)
plt.show()

# %% [markdown]
# ### Interpretation- The city 'Porto Alegra' is having the higher number for houses with 1 bathroom. 'Belo Horizonte' is having higher number of houses with 2 bathrooms.

# %% [markdown]
# ### Relationship of City with Parking Spaces

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "parking spaces", hue = "city", data = df)
plt.show()

# %% [markdown]
# ### Interpretation- The city 'Porto Alegra' is having the higher number for houses with 0 Parking space and also with 1 Parking space. 'Belo Horizonte' is having higher number of houses with 2 Parking spaces.

# %% [markdown]
# ### Relationship of City with Floor

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "floor", hue = "city", data = df)
plt.show()

# %% [markdown]
# ### Interpretation- 'Belo Horizonte' is having higher number of houses with 0 Floor and also with 1 Floor.The city 'Porto Alegra' is having the higher number for houses with 2 Floors.

# %% [markdown]
# ### Relationship of City with Animal

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "animal", hue = "city", data = df)
plt.show()

# %% [markdown]
# ### Interpretation- 'Porto Alegra' is the city which is having the higher number for houses which accepts pets.

# %% [markdown]
# ### Relationship of City with Furniture

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "furniture", hue = "city", data = df)
plt.show()

# %% [markdown]
# ### Interpretation- 'Belo Horizonte' is having higher number of houses which is not Furnished. 'Porto Alegra' is having the more number for houses which is Furnished compared to the other cities.

# %% [markdown]
# # Level 3 Analysis

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# #### For Bachelors

# %% [markdown]
# #### A)

# %%
b1=df[(df['bathroom']==1) & (df['parking spaces']==0)]

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "rooms", hue = "city", data = b1)
plt.show()

# %% [markdown]
# For Bachelors, data filtered for bathroom 1 and no parking space and for the city 'Porto Alegre' is having the higher number of houses with 1 room.

# %% [markdown]
# #### B)

# %%
b2=df[df['floor']==0]

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "rooms", hue = "city", data = b2)
plt.show()

# %% [markdown]
# For Bachelors, data filtered with Floor 0 and the city 'Belo Horizonte' is having higher number of houses with Room 1.

# %% [markdown]
# #### C)

# %%
b3=df[(df['animal']=='acept') & (df['furniture']=='furnished')]

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "rooms", hue = "city", data = b3)
plt.show()

# %% [markdown]
# For Bachelors, data filtered for the houses which are accepting the pets and houses which are furnished. The city 'Porto Alegre' is having the higher number of houses compared to the other cities.

# %% [markdown]
# #### For Mid-Sized Families

# %% [markdown]
# #### A)

# %%
m1=df[(df['bathroom']==2) & (df['parking spaces']==1)]

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "rooms", hue = "city", data = m1)
plt.show()

# %% [markdown]
# For Mid-Sized Family, data filtered for houses with 2 bathrooms and 1 parking space and the city 'Poro Alegre' is having the higher number for houses with 2 rooms.

# %% [markdown]
# #### B)

# %%
m2=df[(df['floor']==0) | (df['floor']==1)]

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "rooms", hue = "city", data = m2)
plt.show()

# %% [markdown]
# For Mid-Sized Family, data filtered for houses with Floor 0 or 1 and the city 'Porto Alegre' is having the higher number of houses with 2 rooms.

# %% [markdown]
# #### C)

# %%
m3=df[(df['animal']=='not acept') & (df['furniture']=='furnished')]

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "rooms", hue = "city", data = m3)
plt.show()

# %% [markdown]
# For Mid-Sized Family, data filtered for houses with pets are not allowed and are furnished and the city 'Porto Alegre' is having the higher number of houses with 2 rooms.

# %% [markdown]
# #### For Large Families

# %% [markdown]
# #### A)

# %%
l1=df[(df['bathroom']==3) | (df['bathroom']==4)]

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "rooms", hue = "city", data = l1)
plt.show()

# %% [markdown]
# For Large Family, data filtered for houses with bathrooms 3 or 4 and the city 'Belo Horizonte' is having the higher number of houses with 3 rooms and 4 rooms.

# %% [markdown]
# #### B)

# %%
l2=df[(df['parking spaces']==2) & (df['floor']==2)]

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "rooms", hue = "city", data = l2)
plt.show()

# %% [markdown]
# For Large Family, data filtered for houses with 2 parking spaces and 2 floored houses and the city 'Belo Horizonte' is having the higher number of houses with 3 rooms and 4 rooms.

# %% [markdown]
# #### C)

# %%
l3=df[(df['animal']=='acept') & (df['furniture']=='furnished')]

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "rooms", hue = "city", data = l3)
plt.show()

# %% [markdown]
# For Large Family, data filtered for houses with pets are allowed and are furnished and the city 'Porto Alegre' is having the higher number of houses with 3 rooms and the city 'Belo Horizonte' is having the higher number of houses with 4 rooms.

# %% [markdown]
# ## LEVEL 1:  Analysis of Numerical Columns

# %% [markdown]
# -> User defined function for calculating mean, median, mode, standard deviation, and count of all null values

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %% [markdown]
# ### Analysis of the 'Area'

# %%
info_of_numerical("area")
# Out:
# The mean of the area is 151.89769975786925
# The median of the area is 80.0
# The mode of the area is 70
# The standard deviation of the area is 844.549115817972
# Number of missing values in the area is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["area"], ax =ax[1], color = "m") 
sns.boxplot(x = df["area"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Outliers Analysis and Treatment:

# %%
mean = int(df.area.mean())
x = df[df["area"] > 700].index
for index in x:
    df.loc[index, "area"] = mean

# %%
info_of_numerical("area")
# Out:
# The mean of the area is 127.75544794188862
# The median of the area is 80.0
# The mode of the area is 70
# The standard deviation of the area is 114.55827894121975
# Number of missing values in the area is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["area"], ax =ax[1], color = "m") 
sns.boxplot(x = df["area"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Interpretation- From the Histogram and the Boxplot analysis, can identify outliers are present and these outliers are treated with the mean value and the area is having their values in between 50 to 150.

# %% [markdown]
# ### Analysis of the 'hoa (R$)'

# %%
info_of_numerical("hoa (R$)")
# Out:
# The mean of the hoa (R$) is 1224.822033898305
# The median of the hoa (R$) is 366.5
# The mode of the hoa (R$) is 0
# The standard deviation of the hoa (R$) is 27477.762415061632
# Number of missing values in the hoa (R$) is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["hoa (R$)"], ax =ax[1], color = "m") 
sns.boxplot(x = df["hoa (R$)"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Outliers Analysis and Treatment:

# %%
mean = int(df.area.mean())
x = df[df["hoa (R$)"] > 3000].index
for index in x:
    df.loc[index, "hoa (R$)"] = mean

# %%
info_of_numerical("hoa (R$)")
# Out:
# The mean of the hoa (R$) is 500.7148910411622
# The median of the hoa (R$) is 351.5
# The mode of the hoa (R$) is 0
# The standard deviation of the hoa (R$) is 544.9333260405858
# Number of missing values in the hoa (R$) is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["hoa (R$)"], ax =ax[1], color = "m") 
sns.boxplot(x = df["hoa (R$)"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Interpretation- From the Histogram and the Boxplot analysis, can identify outliers are present and these outliers are treated with the mean value and the 'hoa' is having their values in between 100 to 700.

# %% [markdown]
# ### Analysis of the 'rent amount (R$)'

# %%
info_of_numerical("rent amount (R$)")
# Out:
# The mean of the rent amount (R$) is 2849.6032082324455
# The median of the rent amount (R$) is 1800.0
# The mode of the rent amount (R$) is 1200
# The standard deviation of the rent amount (R$) is 2859.528061327034
# Number of missing values in the rent amount (R$) is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["rent amount (R$)"], ax =ax[1], color = "m") 
sns.boxplot(x = df["rent amount (R$)"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Outliers Analysis and Treatment:

# %%
mean = int(df.area.mean())
x = df[df["rent amount (R$)"] > 10000].index
for index in x:
    df.loc[index, "rent amount (R$)"] = mean

# %%
info_of_numerical("rent amount (R$)")
# Out:
# The mean of the rent amount (R$) is 2354.2969128329296
# The median of the rent amount (R$) is 1600.0
# The mode of the rent amount (R$) is 127
# The standard deviation of the rent amount (R$) is 1996.2547157158342
# Number of missing values in the rent amount (R$) is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["rent amount (R$)"], ax =ax[1], color = "m") 
sns.boxplot(x = df["rent amount (R$)"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Interpretation- From the Histogram and the Boxplot analysis, can identify outliers are present and these outliers are treated with the mean value and the 'rent amount' is having their values in between 1000 to 3000.

# %% [markdown]
# ### Analysis of the 'property tax (R$)'

# %%
info_of_numerical("property tax (R$)")
# Out:
# The mean of the property tax (R$) is 186.76452784503633
# The median of the property tax (R$) is 86.0
# The mode of the property tax (R$) is 0
# The standard deviation of the property tax (R$) is 361.6002081116756
# Number of missing values in the property tax (R$) is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["property tax (R$)"], ax =ax[1], color = "m") 
sns.boxplot(x = df["property tax (R$)"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Outliers Analysis and Treatment:

# %%
mean = int(df.area.mean())
x = df[df["property tax (R$)"] > 500].index
for index in x:
    df.loc[index, "property tax (R$)"] = mean

# %%
info_of_numerical("property tax (R$)")
# Out:
# The mean of the property tax (R$) is 116.75363196125907
# The median of the property tax (R$) is 86.0
# The mode of the property tax (R$) is 0
# The standard deviation of the property tax (R$) is 113.23047297889947
# Number of missing values in the property tax (R$) is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["property tax (R$)"], ax =ax[1], color = "m") 
sns.boxplot(x = df["property tax (R$)"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Interpretation- From the Histogram and the Boxplot analysis, can identify outliers are present and these outliers are treated with the mean value and the 'property tax' is having their values in between 20 to 150.

# %% [markdown]
# ### Analysis of the 'fire insurance (R$)'

# %%
info_of_numerical("fire insurance (R$)")
# Out:
# The mean of the fire insurance (R$) is 41.95127118644068
# The median of the fire insurance (R$) is 25.0
# The mode of the fire insurance (R$) is 14
# The standard deviation of the fire insurance (R$) is 44.134503754264465
# Number of missing values in the fire insurance (R$) is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["fire insurance (R$)"], ax =ax[1], color = "m") 
sns.boxplot(x = df["fire insurance (R$)"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Outliers Analysis and Treatment:

# %%
mean = int(df.area.mean())
x = df[df["fire insurance (R$)"] > 100].index
for index in x:
    df.loc[index, "fire insurance (R$)"] = mean

# %%
info_of_numerical("fire insurance (R$)")
# Out:
# The mean of the fire insurance (R$) is 39.19158595641647
# The median of the fire insurance (R$) is 25.0
# The mode of the fire insurance (R$) is 127
# The standard deviation of the fire insurance (R$) is 34.57079826486752
# Number of missing values in the fire insurance (R$) is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["fire insurance (R$)"], ax =ax[1], color = "m") 
sns.boxplot(x = df["fire insurance (R$)"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Interpretation- From the Histogram and the Boxplot analysis, can identify outliers are present and these outliers are treated with the mean value and the 'fire insurance' is having their values in between 18 to 48.

# %% [markdown]
# ### Analysis of the 'total (R$)'

# %%
info_of_numerical("total (R$)")
# Out:
# The mean of the total (R$) is 4303.3265738498785
# The median of the total (R$) is 2348.0
# The mode of the total (R$) is 2633
# The standard deviation of the total (R$) is 27679.63993475239
# Number of missing values in the total (R$) is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["total (R$)"], ax =ax[1], color = "m") 
sns.boxplot(x = df["total (R$)"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Outliers Analysis and Treatment:

# %%
mean = int(df.area.mean())
x = df[df["total (R$)"] > 2000].index
for index in x:
    df.loc[index, "total (R$)"] = mean

# %%
info_of_numerical("total (R$)")
# Out:
# The mean of the total (R$) is 669.0487288135594
# The median of the total (R$) is 151.0
# The mode of the total (R$) is 151
# The standard deviation of the total (R$) is 650.8305858321514
# Number of missing values in the total (R$) is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               
sns.histplot(x = df["total (R$)"], ax =ax[1], color = "m") 
sns.boxplot(x = df["total (R$)"], ax = ax[0], color = "g") 
plt.show()

# %% [markdown]
# ### Interpretation- From the Histogram and the Boxplot analysis, can identify outliers are present and these outliers are treated with the mean value and the 'total' is having their values in between 250 to 1300.

# %% [markdown]
# ### CAT-NUM ANALYSIS (relationship between categorical and numerical data)

# %% [markdown]
# ### Relationship of City with 'rent amount (R$)'

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 7))
sns.histplot(x = df["rent amount (R$)"], hue = df["city"], ax = ax[0])
sns.boxplot(y = df["rent amount (R$)"], x = df["city"], ax = ax[1])
plt.show()

# %% [markdown]
# ### Interpretation- From the Histogram and Boxplot analysis, can identify ouliers are present for the 'rent amount' column so after finding the mean value and treated the outliers with mean, for the city 'Porto Alegre' the 'rent amount' is in between 1500 to 2500 and for the city 'Campinas', the 'rent amount' is in between 1400 to 2600 and for 'Belo Horizonte', it is in between 1800 to 3800.

# %% [markdown]
# ### Relationship of City with 'total (R$)'

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 7))
sns.histplot(x = df["total (R$)"], hue = df["city"], ax = ax[0])
sns.boxplot(y = df["total (R$)"], x = df["city"], ax = ax[1])
plt.show()

# %% [markdown]
# ### Interpretation- From the Histogram and Boxplot analysis, can identify ouliers are present for the 'total' column so after finding the mean value and treated the outliers with mean, for the city 'Porto Alegre', the 'total' is in between 250 to 1350 and for the city 'Campinas', the 'total' is in between 250 to 1300 and for 'Belo Horizonte', it is in between 250 to 1150.

# %% [markdown]
# ## Level 3 Further Analysis

# %% [markdown]
# #### For Bachelors

# %% [markdown]
# 1. With the minimal cost of rent amount for Bachelors, how the city will be choosen with the houses based on the rooms and bathrooms?
# 2. How the house Furniture and Animal allow affects the criteria for the cities to be selected?

# %% [markdown]
# #### A)

# %%
bach1=df[(df['rooms']==1) & (df['bathroom']==1)]

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = bach1["rent amount (R$)"], hue = bach1["city"], ax = ax[0])
sns.boxplot(y = bach1["rent amount (R$)"], x = bach1["city"], ax = ax[1])
plt.show()

# %% [markdown]
# For Bachelors, data filtered for room 1 and bathroom 1 and for the city 'Porto Alegre' is having the higher number of houses with rent amount in between 1100 to 1500. For the city, 'Campinas' is having houses with rent amount in between 900 to 1300 and for 'Belo Horizonte' its in between 1100 to 1500.

# %% [markdown]
# #### B)

# %%
bach2=df[(df['animal']=='acept') & (df['furniture']=='furnished')]

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = bach2["rent amount (R$)"], hue = bach2["city"], ax = ax[0])
sns.boxplot(y = bach2["rent amount (R$)"], x = bach2["city"], ax = ax[1])
plt.show()

# %% [markdown]
# For Bachelors, data filtered for houses which allows pets and houses which are furnished and for the city 'Porto Alegre' is having the higher number of houses with rent amount in between 2200 to 3000. For the city, 'Campinas' is having houses with rent amount in between 2200 to 4000 and for 'Belo Horizonte' its in between 4000 to 8000.

# %% [markdown]
# ### Interpretation- For Bachelors, the city 'Porto Alegre' is more convenient to get the houses with the requirements in less amount of rent amount.

# %% [markdown]
# #### For Mid-Sized Families

# %% [markdown]
# 1. For Mid-sized families, how the rooms, bathrooms and parking spaces considered?
# 2. How many floored houses are taken into the requirement for this family?

# %% [markdown]
# #### A)

# %%
bach3=df[(df['rooms']==2) & (df['bathroom']==2) & (df['parking spaces']==1)]

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = bach3["rent amount (R$)"], hue = bach3["city"], ax = ax[0])
sns.boxplot(y = bach3["rent amount (R$)"], x = bach3["city"], ax = ax[1])
plt.show()

# %% [markdown]
# For Mid-Sized families, data filtered for rooms 2 and bathrooms 2 and parking space with 1 and for the city 'Porto Alegre' is having the higher number of houses with rent amount in between 1400 to 1600. For the city, 'Campinas' is having houses with rent amount in between 1500 to 2100 and for 'Belo Horizonte' its in between 1500 to 1900.

# %% [markdown]
# #### B)

# %%
bach4=df[(df['floor']==0) | (df['floor']==1) & (df['furniture']=='furnished')]

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = bach4["rent amount (R$)"], hue = bach4["city"], ax = ax[0])
sns.boxplot(y = bach4["rent amount (R$)"], x = bach4["city"], ax = ax[1])
plt.show()

# %% [markdown]
# For Mid-Sized families, data filtered for floors 0 or 1 and houses which are furnished and for the city 'Porto Alegre' is having the higher number of houses with rent amount in between 3000 to 4500. For the city, 'Campinas' is having houses with rent amount in between 4500 to 8000 and for 'Belo Horizonte' its in between 2000 to 4500.

# %% [markdown]
# ### Interpretation- For Mid-Sized families, the city 'Porto Alegre' is more convenient to get the houses with the  requirements in less amount of rent amount.

# %% [markdown]
# #### For Large Families

# %% [markdown]
# 1. For Large family, how the number of rooms and bathrooms affected the rent amount?
# 2. Based on the floor and furniture how the city with less rent amount chosen?

# %% [markdown]
# #### A)

# %%
bach5=df[(df['rooms']==3) | (df['rooms']==4) & (df['bathroom']==3) | (df['bathroom']==4)]

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = bach5["rent amount (R$)"], hue = bach5["city"], ax = ax[0])
sns.boxplot(y = bach5["rent amount (R$)"], x = bach5["city"], ax = ax[1])
plt.show()

# %% [markdown]
# For Large families, data filtered for rooms 3 or 4 and bathrooms 3 or 4 and for the city 'Belo Horizonte' is having the higher number of houses with rent amount in between 3000 to 5500. For the city, 'Campinas' is having houses with rent amount in between 2000 to 4000 and for 'Porto Alegre' its in between 3000 to 4500.

# %% [markdown]
# #### B)

# %%
bach6=df[(df['floor']==1) | (df['floor']==2) & (df['animal']=='acept') & (df['furniture']=='furnished')]

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
sns.histplot(x = bach6["rent amount (R$)"], hue = bach6["city"], ax = ax[0])
sns.boxplot(y = bach6["rent amount (R$)"], x = bach6["city"], ax = ax[1])
plt.show()

# %% [markdown]
# For Large families, data filtered for floor 1 or 2 and houses which allows pets and are furnished and for the city 'Belo Horizonte' is having the higher number of houses with rent amount in between 1500 to 2200. For the city, 'Campinas' is having houses with rent amount in between 1400 to 1900 and for 'Porto Alegre' its in between 1500 to 2100.

# %% [markdown]
# ### Interpretation- For Large families, the city 'Belo Horizonte' is more convenient to get the houses with the requirements in appropriate amount of rent amount.
